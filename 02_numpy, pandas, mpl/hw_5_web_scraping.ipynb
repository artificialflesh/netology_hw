# %%
import pandas as pd
import requests
from time import sleep
from bs4 import BeautifulSoup

# %% [markdown]
# ##### Обязательная часть
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# дата - заголовок - ссылка на материал
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
def get_habr_articles(search:list):
    '''Извлекает статьи из поисковой выдачи habr.com.
    search принимает список поисковых запросов в формате list'''
    
    articles = []
    for query in search:
        res = requests.get(f'https://habr.com/ru/search/?q={query}')
        soup = BeautifulSoup(res.text)
        articles += soup.find_all('article', class_='tm-articles-list__item')
        sleep(0.3)
    return articles

# %%
request_list = ['python', 'аналитик данных', 'машинное обучение']

# %%
habr_articles = get_habr_articles(request_list)

# %%
def articles_to_df(articles):
    '''Переводит список статей в data frame со столбцами, содержащими дату, заголовок и ссылку на материал'''
    
    habr_search = pd.DataFrame()

    for el in articles:
        date = el.find('time')['title']
        title = el.find('a', class_='tm-article-snippet__title-link')
        span = title.find('span').text
        title_link = el.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2')
        link = 'https://habr.com' + title_link.find('a')['href']
        row = {'date': date, 'title': span, 'link': link}
        habr_search = pd.concat([habr_search, pd.DataFrame([row])])
    return habr_search.reset_index(drop=True).drop_duplicates(subset=['title'])

# %%
articles_to_df(habr_articles).head(20)
# Out:
#                  date                                              title  \
# 0   2022-05-06, 06:00                       Respect Validation на Python
# 1   2021-12-13, 09:00  Жаждущим автоматизации: открытый урок «ChatOps...
# 2   2022-01-20, 18:37  Курс «Python для инженеров». Старт 3 потока 31...
# 3   2020-04-21, 18:35  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 4   2021-07-06, 13:29  Python Community Meetup 8/07: видео и материал...
# 5   2022-01-13, 18:35  Открытый урок «Пишем Custom Prometheus Exporte...
# 6   2020-12-04, 21:03  Python как компилируемый статически типизирова...
# 7   2022-03-08, 12:13  Вышел мартовский релиз расширения Python для V...
# 8   2020-03-03, 13:22   ...  начале этого года Python сместил Java и ...
# 9   2021-11-16, 16:09  EPAM разработала бесплатный курс по программир...
# 10  2020-06-03, 09:00  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 11  2020-11-13, 10:10  Создатель Python Гвидо ван Россум выходит на р...
# 12  2019-10-31, 10:02  Создатель Python Гвидо ван Россум ушел из Drop...
# 13  2021-10-06, 12:36          Вышел язык программирования Python 3.10.0
# 14  2021-10-11, 10:02  Python вышел на первое место рейтинга TIOBE, и...
# 15  2020-09-16, 16:48  Астрономам порекомендовали меньше использовать...
# 16  2022-01-15, 19:00  Разработчик предложил устроить коммунистическу...
# 17  2022-03-18, 18:31  24 марта Слёрм проведёт открытый урок «Первый ...
# 18  2022-04-22, 14:42  TechnoMeetsPython. Онлайн митап о Python-разра...
# 19  2021-09-27, 09:03  «Разработчикам вход запрещен» или курс «Python...
#
#                                                  link
# 0                    https://habr.com/ru/post/664426/
# 1   https://habr.com/ru/company/southbridge/news/t...
# 2   https://habr.com/ru/company/southbridge/news/t...
# 3                  https://habr.com/ru/news/t/498364/
# 4   https://habr.com/ru/company/raiffeisenbank/new...
# 5   https://habr.com/ru/company/southbridge/news/t...
# 6                  https://habr.com/ru/news/t/531402/
# 7                  https://habr.com/ru/news/t/654707/
# 8   https://habr.com/ru/company/itsumma/news/t/490...
# 9   https://habr.com/ru/company/epam_systems/news/...
# 10                 https://habr.com/ru/news/t/505096/
# 11                 https://habr.com/ru/news/t/527858/
# 12                 https://habr.com/ru/news/t/473926/
# 13                 https://habr.com/ru/news/t/581862/
# 14                 https://habr.com/ru/news/t/582682/
# 15                 https://habr.com/ru/news/t/519414/
# 16                 https://habr.com/ru/news/t/645777/
# 17  https://habr.com/ru/company/southbridge/news/t...
# 18                 https://habr.com/ru/news/t/662437/
# 19  https://habr.com/ru/company/southbridge/news/t...

# %% [markdown]
# ##### Дополнительная часть
# Функция из обязательной части задания должна быть расширена следующим образом:
# - кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить материалы с первых 4 страниц результатов;
# - в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# дата - заголовок - ссылка на материал - текст материала - количество лайков

# %%
def get_habr_articles(search:list, pages:int):
    '''Извлекает статьи из поисковой выдачи habr.com.
    search принимает список поисковых запросов в формате list
    pages принимает количество страниц поиска, с которых необходимо забрать статьи'''
    
    articles = []
    for query in search:
        for i in range(1, pages+1):
            res = requests.get(f'https://habr.com/ru/search/page{i}/?q={query}')
            soup = BeautifulSoup(res.text)
            articles += soup.find_all('article', class_='tm-articles-list__item')
            sleep(0.3)
    return articles

# %%
request_list = ['python', 'аналитик данных']

# %%
habr_articles = get_habr_articles(request_list, 2)

# %%
def articles_to_df(articles):
    '''Переводит список статей в data frame со столбцами, содержащими дату, заголовок, ссылку на материал,
    текст материала и рейтинг статьи'''
        
    habr_search = pd.DataFrame()
    
    for el in articles:
        date = el.find('time')['title']
        title = el.find('a', class_='tm-article-snippet__title-link')
        span = title.find('span').text
        title_link = el.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2')
        link = 'https://habr.com' + title_link.find('a')['href']
        
        # получение текста и количества лайков статьи из link
        ar_req = requests.get(link)
        sleep(0.3)
        ar_soup = BeautifulSoup(ar_req.text)
        ar_body = ar_soup.find('div', class_='tm-article-body')
        ar_text = ar_body.text.strip()
        ar_rating = ar_soup.find('div', class_='tm-article-sticky-panel')
        ar_likes = ar_rating.find('span').text
        
        row = {'date': date, 'title': span, 'link': link, 'text': ar_text, 'likes': ar_likes}
        habr_search = pd.concat([habr_search, pd.DataFrame([row])])
    return habr_search.reset_index(drop=True).drop_duplicates(subset=['title'])

# %%
articles_to_df(habr_articles).head(20)
# Out:
#                  date                                              title  \
# 0   2022-05-06, 06:00                       Respect Validation на Python
# 1   2021-12-13, 09:00  Жаждущим автоматизации: открытый урок «ChatOps...
# 2   2022-01-20, 18:37  Курс «Python для инженеров». Старт 3 потока 31...
# 3   2020-04-21, 18:35  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 4   2021-07-06, 13:29  Python Community Meetup 8/07: видео и материал...
# 5   2022-01-13, 18:35  Открытый урок «Пишем Custom Prometheus Exporte...
# 6   2020-12-04, 21:03  Python как компилируемый статически типизирова...
# 7   2022-03-08, 12:13  Вышел мартовский релиз расширения Python для V...
# 8   2020-03-03, 13:22   ...  начале этого года Python сместил Java и ...
# 9   2021-11-16, 16:09  EPAM разработала бесплатный курс по программир...
# 10  2020-06-03, 09:00  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 11  2020-11-13, 10:10  Создатель Python Гвидо ван Россум выходит на р...
# 12  2019-10-31, 10:02  Создатель Python Гвидо ван Россум ушел из Drop...
# 13  2021-10-06, 12:36          Вышел язык программирования Python 3.10.0
# 14  2021-10-11, 10:02  Python вышел на первое место рейтинга TIOBE, и...
# 15  2020-09-16, 16:48  Астрономам порекомендовали меньше использовать...
# 16  2022-01-15, 19:00  Разработчик предложил устроить коммунистическу...
# 17  2022-03-18, 18:31  24 марта Слёрм проведёт открытый урок «Первый ...
# 18  2022-04-22, 14:42  TechnoMeetsPython. Онлайн митап о Python-разра...
# 19  2021-09-27, 09:03  «Разработчикам вход запрещен» или курс «Python...
#
#                                                  link  \
# 0                    https://habr.com/ru/post/664426/
# 1   https://habr.com/ru/company/southbridge/news/t...
# 2   https://habr.com/ru/company/southbridge/news/t...
# 3                  https://habr.com/ru/news/t/498364/
# 4   https://habr.com/ru/company/raiffeisenbank/new...
# 5   https://habr.com/ru/company/southbridge/news/t...
# 6                  https://habr.com/ru/news/t/531402/
# 7                  https://habr.com/ru/news/t/654707/
# 8   https://habr.com/ru/company/itsumma/news/t/490...
# 9   https://habr.com/ru/company/epam_systems/news/...
# 10                 https://habr.com/ru/news/t/505096/
# 11                 https://habr.com/ru/news/t/527858/
# 12                 https://habr.com/ru/news/t/473926/
# 13                 https://habr.com/ru/news/t/581862/
# 14                 https://habr.com/ru/news/t/582682/
# 15                 https://habr.com/ru/news/t/519414/
# 16                 https://habr.com/ru/news/t/645777/
# 17  https://habr.com/ru/company/southbridge/news/t...
# 18                 https://habr.com/ru/news/t/662437/
# 19  https://habr.com/ru/company/southbridge/news/t...
#
#                                                  text likes
# 0   В данной статье я расскажу вам историю "как я ...   +19
# 1   21 декабря Слёрм проведёт открытый урок «ChatO...    +9
# 2   Курс нацелен дать максимальную пользу, поэтому...   +10
# 3   20 апреля 2020 года, спустя почти десять лет п...   +19
# 4   Первый открытый онлайн-митап сообщества, для к...    +3
# 5   19 января Слёрм проведёт открытый урок «Пишем ...   +10
# 6   По данным широко известного в узких кругах Tio...   +16
# 7   Вышел выпуск расширения Python для Visual Stud...     0
# 8   Согласно отчету RedMonk за январь 2020 года, P...   +31
# 9   Компания EPAM запустила бесплатный курс для са...    +3
# 10  31 мая 2020 года разработчик Джош Мур (Josh Mo...   +19
# 11  Создатель языка программирования Python Гвидо ...   +21
# 12  Создатель языка программирования Python Гвидо ...   +23
# 13  В официальном блоге языка Python заявили о вых...   +12
# 14  TIOBE представила рейтинг популярности языков ...   +17
# 15  Астрономы из Лейденской обсерватории опубликов...   +22
# 16  14 января 2022 года разработчик jokteur на Git...    +7
# 17  Думаете, написать свою первую программу на Pyt...   +14
# 18  27 апреля в 18:00 собираем питонистов на YouTu...    +2
# 19  Полгода назад мы анонсировали первый поток кур...   +11
